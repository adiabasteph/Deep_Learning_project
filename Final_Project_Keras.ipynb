# %% [markdown]
# <div align=center><font size = 6>Build a Regression Model in Keras</font></dev>

# %% [markdown]
# <div><font size=3><strong>Table Of Contents</strong></font></div>
#
# 1. Some useful functions
# 2. Loading input corpus
# 3. Reviewing the loaded data
# 4. Normalizing input data
# 5. Splitting corpus into traning set and testing set
# 6. A - Experiment with a baseline model
# 7. B - Experiment with Normalized Data
# 8. C. Increate the number of epochs
# 9. D. Increase the number of hidden layers
# 10. Discussion

# %% [markdown]
# <strong>The dataset the compressive strength of different samples of concrete based on the volumes of the different components that include:</strong>
#
# <strong>1. Cement</strong>
#
# <strong>2. Blast Furnace Slag</strong>
#
# <strong>3. Fly Ash</strong>
#
# <strong>4. Water</strong>
#
# <strong>5. Superplasticizer</strong>
#
# <strong>6. Coarse Aggregate</strong>
#
# <strong>7. Fine Aggregate</strong>

# %% [markdown]
# # Import some useful functions

# %% [markdown]
# Let's start by importing the libraries : os, keras, pandas, numpy, scikit_learn, etc.

# %%
import time
import os
import pandas as pd
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
# Define some components for the analysis

COL_NAME_CEMENT = "Cement"
COL_NAME_BLAST_FURNACE_SLAG = "Blast Furnace Slag"
COL_NAME_FLY_ASH = "Fly Ash"
COL_NAME_WATER = "Water"
COL_NAME_SUPERPLASTICIZER = "Superplasticizer"
COL_NAME_COARSE_AGGREGATE = "Coarse Aggregate"
COL_NAME_FINE_AGGREGATE = "Fine Aggregate"
COL_NAME_AGE = "Age"
COL_NAME_STRENGTH = "Strength"

COL_NAME_EXPERIMENT = "Experiment"
COL_NAME_MSE = "Mean MSE"
COL_NAME_RMSE = "Std Deviation MSE"

# This dataframe contains three columns: name_of_experiments, mse, rmse

header_of_concrete_data_mse_and_rmse = [COL_NAME_EXPERIMENT, COL_NAME_MSE, COL_NAME_RMSE]
concrete_data_mse_and_rmse = pd.DataFrame(columns=header_of_concrete_data_mse_and_rmse, data=[])

#Get round with given number of decimal digits 
    
def get_round(score, num_of_digits=2):
    return round(score, num_of_digits)


#Estimate the mean of the data

def get_mean(concrete_data_mse_scores):

    if concrete_data_mse_scores:
        return get_round(np.mean(concrete_data_mse_scores))
    return None
    
    
#Estimate the standard deviation
def get_standard_deviation(concrete_data_mse_scores):
    
    if concrete_data_mse_scores:
        return get_round(np.std(concrete_data_mse_scores))
    return None


#Build baseline model that contains:One hidden layer of 10 nodes, and a ReLU activation function.
#Use the adam optimizer and the mean squared error as the loss function.


def build_model_with_one_hidden_layer(num_of_features=3):
       
    # Create model
    model = Sequential()

    model.add(Dense(10, activation="relu", input_shape=(num_of_features,)))
    model.add(Dense(1))

    # Compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model


 # Build model that contains:Three hidden layers, each of 10 nodes and ReLU activation function.
#Use the adam optimizer and the mean squared error as the loss function.


def build_model_with_three_hidden_layers(num_of_features=3):
   
    
    # Create the model
    model = Sequential()

    model.add(Dense(10, activation="relu", input_shape=(num_of_features,)))
    model.add(Dense(10, activation="relu"))
    model.add(Dense(10, activation="relu"))
    model.add(Dense(1))

    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model


#Generate report (dataframe) of two metrics: The mean and the standard deviation of the mean squared errors
     
def get_mean_squared_error(compiled_model, X, y, epochs=50, verbose=1):
      
    
    # 1. Randomly split the data into a training and test sets by holding 30% 
    # of the data for testing. You can use the train_test_split helper function 
    # from Scikit-learn.    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24)   
    print("Training set: ", X_train.shape, y_train.shape)
    print("Testing set: ", X_test.shape, y_test.shape)
    
    
    # 2. Train the model on the training data using 50 epochs.
    # Note that: given model which is compiled
    # Fit the built model with training set
    model.fit(X_train, y_train, epochs=epochs, verbose=verbose)    

    # 3. Evaluate the model on the test data and compute the mean squared error 
    # between the predicted concrete strength and the actual concrete strength. 
    # You can use the mean_squared_error function from Scikit-learn.    
    y_hat = model.predict(X_test)    
    mse = mean_squared_error(y_test, y_hat)
    
    # Return the mean squared error
    return mse

 #Generate the mean and the standard deviation of the mean squared errors, Then Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.  

def get_mean_and_std_of_mse(df_X, 
                            df_y, 
                            compiled_model,                
                            max_iteration=50, 
                            epochs=50, 
                            verbose=0):
     
    concrete_data_mean_squared_errors = []
    for i in range(max_iteration):
        start_time = time.time()
        print("-" * 36)
        print("Processing current number of iteration : {}".format(i+1))        
        mse = get_mean_squared_error(compiled_model, df_X, df_y, epochs=epochs, verbose=verbose)
        concrete_data_mean_squared_errors.append(mse)
        print("Duration (seconds): {}".format(time.time()-start_time))

    print("Finished - {} times.\nAnd the list of mean squared errors : {}".format(max_iteration,
                                                                                  concrete_data_mean_squared_errors))
    mean_mse = get_mean(concrete_data_mean_squared_errors)
    std_mse = get_standard_deviation(concrete_data_mean_squared_errors)

    print("-" * 72)
    print("The mean and the standard deviation of the mean squared errors are: {} and {}, respectively".format(
           mean_mse, std_mse))
    
    return mean_mse, std_mse

 
#Generate report (dataframe) of two metrics: The mean and the standard deviation of the mean squared errors

def get_report(name_of_experiment, mean_mse, std_mse):
   
    values = [[name_of_experiment, mean_mse, std_mse]]

    return pd.DataFrame(columns=header_of_concrete_data_mse_and_rmse, data=values)

# %% [markdown]
# # Loading input corpus

# %% [markdown]
# Let's assign the path of input corpus. Because we re-use after dowloading the input corpus.

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# Let's read input data into a dataframe

# %% [markdown]
# # Reviewing the loaded data

# %%
concrete_data.columns
# Out:
# Index(['Cement', 'Blast Furnace Slag', 'Fly Ash', 'Water', 'Superplasticizer',
#        'Coarse Aggregate', 'Fine Aggregate', 'Age', 'Strength'],
#       dtype='object')

# %%
concrete_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cement              1030 non-null   float64
#  1   Blast Furnace Slag  1030 non-null   float64
#  2   Fly Ash             1030 non-null   float64
#  3   Water               1030 non-null   float64
#  4   Superplasticizer    1030 non-null   float64
#  5   Coarse Aggregate    1030 non-null   float64
#  6   Fine Aggregate      1030 non-null   float64
#  7   Age                 1030 non-null   int64
#  8   Strength            1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.head(5)
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has "540" cubic meter of cement, "0" cubic meter of blast furnace slag, "0" cubic meter of fly ash, "162" cubic meter of water, "2.5" cubic meter of superplaticizer, "1040" cubic meter of coarse aggregate, "676" cubic meter of fine aggregate. Such a concrete mix which is "28" days old, has a compressive strength of "79.99" MPa.

# %%
print("(row, column) = {}".format(concrete_data.shape))
# Out:
# (row, column) = (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on when splitting with 30% for the data of testing.

# %% [markdown]
# Let's check the data for any missing value

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# As you see, the above input corpus look pretty good to train the model. However, we could use the normalization technique to normalize it.

# %% [markdown]
# # Normalizing input data

# %%
concrete_data_column_names = concrete_data.columns
concrete_data_column_names
# Out:
# Index(['Cement', 'Blast Furnace Slag', 'Fly Ash', 'Water', 'Superplasticizer',
#        'Coarse Aggregate', 'Fine Aggregate', 'Age', 'Strength'],
#       dtype='object')

# %% [markdown]
# ## Splitting into predictors and target

# %% [markdown]
# Filtering the title of column names of dataframe predictors

# %%
concrete_data_col_names_predictors = [x for x in concrete_data_column_names 
                                if x != COL_NAME_STRENGTH]

# %%
concrete_data_col_names_predictors
# Out:
# ['Cement',
#  'Blast Furnace Slag',
#  'Fly Ash',
#  'Water',
#  'Superplasticizer',
#  'Coarse Aggregate',
#  'Fine Aggregate',
#  'Age']

# %%
concrete_data_predictors = concrete_data[concrete_data_col_names_predictors]

# %%
concrete_data_target = concrete_data[[COL_NAME_STRENGTH]]

# %% [markdown]
# Separating the data in two dataframes: predictors and target

# %%
concrete_data_predictors.head(5)
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
concrete_data_target.head(5)
# Out:
#    Strength
# 0     79.99
# 1     61.89
# 2     40.27
# 3     41.05
# 4     44.30

# %% [markdown]
# ## Applying normalization method
#
# Recall that one way to normalize the data is by subtracting the mean from the individual predictors and dividing by the standard deviation.

# %%
concrete_data_predictors_norm = (concrete_data_predictors - concrete_data_predictors.mean())/concrete_data_predictors.std()

# %%
concrete_data_predictors_norm.head(5)
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# # A - Experiment with a baseline model
#
# Use the Keras library to build a neural network with the following:
#
#    + One hidden layer of **10 nodes**, and a **ReLU activation function**
#
#    + Use the **adam optimizer** and the **mean squared error as the loss function**.
#
# 1. **Randomly split** the data into a training and test sets by holding **30% of the data for testing**. You can use the train_test_split helper function from Scikit-learn.
#
# 2. Train the model on the training data using **50 epochs**.
#
# 3. Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.
#
# 4. Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.
#
# 5. Report the mean and the standard deviation of the mean squared errors.

# %% [markdown]
# ## Building and Training with the baseline model

# %%
num_of_features = len(concrete_data.columns) - 1
print("Number of features for input layer : ", num_of_features)
# Out:
# Number of features for input layer :  8

# %%
# Evaluate the compiled model
model = build_model_with_one_hidden_layer(num_of_features=num_of_features)

mean_mse, std_mse = get_mean_and_std_of_mse(concrete_data_predictors, 
                                            concrete_data_target, 
                                            model, 
                                            max_iteration=50, 
                                            epochs=50, verbose=0)
# Out:
# 2022-02-28 22:07:43.293691: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ------------------------------------
# Processing current number of iteration : 1
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.3787529468536377
# ------------------------------------
# Processing current number of iteration : 2
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.320302963256836
# ------------------------------------
# Processing current number of iteration : 3
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.5278122425079346
# ------------------------------------
# Processing current number of iteration : 4
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.3300559520721436
# ------------------------------------
# Processing current number of iteration : 5
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.2837200164794922
# ------------------------------------
# Processing current number of iteration : 6
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.302821159362793
# ------------------------------------
# Processing current number of iteration : 7
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.298633098602295
# ------------------------------------
# Processing current number of iteration : 8
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.2986276149749756
# ------------------------------------
# Processing current number of iteration : 9
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.328765869140625
# ------------------------------------
# Processing current number of iteration : 10
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.5316517353057861
# ------------------------------------
# Processing current number of iteration : 11
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.29292893409729
# ------------------------------------
# Processing current number of iteration : 12
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.3177509307861328
# ------------------------------------
# Processing current number of iteration : 13
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.2999849319458008
# ------------------------------------
# Processing current number of iteration : 14
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.293276309967041
# ------------------------------------
# Processing current number of iteration : 15
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.7440681457519531
# ------------------------------------
# Processing current number of iteration : 16
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.74992299079895
# ------------------------------------
# Processing current number of iteration : 17
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.4777729511260986
# ------------------------------------
# Processing current number of iteration : 18
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.4468131065368652
# ------------------------------------
# Processing current number of iteration : 19
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.4952731132507324
# ------------------------------------
# Processing current number of iteration : 20
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.354529857635498
# ------------------------------------
# Processing current number of iteration : 21
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.2846832275390625
# ------------------------------------
# Processing current number of iteration : 22
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.1049342155456543
# ------------------------------------
# Processing current number of iteration : 23
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 5.718219041824341
# ------------------------------------
# Processing current number of iteration : 24
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 9.453689098358154
# ------------------------------------
# Processing current number of iteration : 25
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 10.711745023727417
# ------------------------------------
# Processing current number of iteration : 26
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 13.150285005569458
# ------------------------------------
# Processing current number of iteration : 27
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 11.279381036758423
# ------------------------------------
# Processing current number of iteration : 28
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 4.695685863494873
# ------------------------------------
# Processing current number of iteration : 29
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.8017408847808838
# ------------------------------------
# Processing current number of iteration : 30
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.7500200271606445
# ------------------------------------
# Processing current number of iteration : 31
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.9099268913269043
# ------------------------------------
# Processing current number of iteration : 32
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 5.249587297439575
# ------------------------------------
# Processing current number of iteration : 33
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.9813449382781982
# ------------------------------------
# Processing current number of iteration : 34
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.8665170669555664
# ------------------------------------
# Processing current number of iteration : 35
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.683720111846924
# ------------------------------------
# Processing current number of iteration : 36
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 4.682220935821533
# ------------------------------------
# Processing current number of iteration : 37
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.127716064453125
# ------------------------------------
# Processing current number of iteration : 38
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.437049150466919
# ------------------------------------
# Processing current number of iteration : 39
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.484611988067627
# ------------------------------------
# Processing current number of iteration : 40
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.5767009258270264
# ------------------------------------
# Processing current number of iteration : 41
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.3762543201446533
# ------------------------------------
# Processing current number of iteration : 42
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.8252782821655273
# ------------------------------------
# Processing current number of iteration : 43
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.5541009902954102
# ------------------------------------
# Processing current number of iteration : 44
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.3957350254058838
# ------------------------------------
# Processing current number of iteration : 45
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.482370138168335
# ------------------------------------
# Processing current number of iteration : 46
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.3669230937957764
# ------------------------------------
# Processing current number of iteration : 47
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.4556410312652588
# ------------------------------------
# Processing current number of iteration : 48
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.3436169624328613
# ------------------------------------
# Processing current number of iteration : 49
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.6577789783477783
# ------------------------------------
# Processing current number of iteration : 50
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.3397858142852783
# Finished - 50 times.
# And the list of mean squared errors : [121.77079329269459, 80.60619210803286, 66.63905797164797, 57.890389741631616, 63.145914180256625, 49.360263229804, 49.083903597315306, 49.857490799093995, 49.51718226674093, 50.21414693159494, 49.541070766391265, 49.89576750177735, 50.63530595708623, 50.08935205907424, 51.46174772156777, 51.733576455666345, 49.49369702579233, 49.290404405717126, 53.546324182878365, 52.105144910970694, 57.019883125049255, 52.42474481244109, 51.12918544675413, 52.00097699776546, 54.78085029950044, 49.242579598092014, 49.15555953880944, 50.71849893479965, 48.86907677008511, 51.265770557301444, 57.02047983585068, 49.986461316497746, 49.4581673890289, 49.97595641784396, 55.34597812946428, 54.211692380545685, 49.32434689925945, 49.28309421032164, 58.134227650336555, 49.04035724699302, 48.641838266674064, 51.532028351109645, 50.34121981796687, 49.346375583522985, 48.55319471200206, 49.06472730970112, 51.92239211086974, 49.18728062245794, 49.314988760173144, 48.82381505344307]
# ------------------------------------------------------------------------
# The mean and the standard deviation of the mean squared errors are: 53.62 and 11.17, respectively

# %% [markdown]
# ## Report the mean and the standard deviation of the mean squared errors

# %%
name_of_experiment = "Baseline of the Raw Data with 50 epochs"

# Report the mean and the standard deviation of the mean squared errors
concrete_data_result_baseline = get_report(name_of_experiment, mean_mse, std_mse)
concrete_data_result_baseline
# Out:
#                                 Experiment  Mean MSE  Std Deviation MSE
# 0  Baseline of the Raw Data with 50 epochs     53.62              11.17

# %%
# Concat baseline dataframe into result
concrete_data_mse_and_rmse = pd.concat([concrete_data_mse_and_rmse, concrete_data_result_baseline], axis=0)

# Review the result dataframe
concrete_data_mse_and_rmse.reset_index(drop=True)
# Out:
#                                 Experiment  Mean MSE  Std Deviation MSE
# 0  Baseline of the Raw Data with 50 epochs     53.62              11.17

# %% [markdown]
# # B - Experiment with Normalized Data
#
# Repeat Part A but use a normalized version of the data. Recall that one way to normalize the data is by subtracting the mean from the individual predictors and dividing by the standard deviation.
#
# How does the mean of the mean squared errors compare to that from Step A?

# %% [markdown]
# ## Normalize the data
# by substracting the mean and dividing by the standard deviation.

# %% [markdown]
# ### Before normalization

# %%
concrete_data_predictors.head(5)
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %% [markdown]
# ### After normalization

# %%
concrete_data_predictors_norm.head(5)
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# ## Building and Training with the baseline model after normalizing the data with 50 epochs

# %%
# Evaluate the compiled model
model = build_model_with_one_hidden_layer(num_of_features=num_of_features)

mean_mse, std_mse = get_mean_and_std_of_mse(concrete_data_predictors_norm, 
                                            concrete_data_target, 
                                            model, 
                                            max_iteration=50, 
                                            epochs=50, verbose=0)
# Out:
# ------------------------------------
# Processing current number of iteration : 1
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.7124340534210205
# ------------------------------------
# Processing current number of iteration : 2
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.3309669494628906
# ------------------------------------
# Processing current number of iteration : 3
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.322847604751587
# ------------------------------------
# Processing current number of iteration : 4
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.3305869102478027
# ------------------------------------
# Processing current number of iteration : 5
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.3468000888824463
# ------------------------------------
# Processing current number of iteration : 6
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.365002155303955
# ------------------------------------
# Processing current number of iteration : 7
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.6997711658477783
# ------------------------------------
# Processing current number of iteration : 8
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.3985059261322021
# ------------------------------------
# Processing current number of iteration : 9
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.3194553852081299
# ------------------------------------
# Processing current number of iteration : 10
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.2996549606323242
# ------------------------------------
# Processing current number of iteration : 11
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.3628849983215332
# ------------------------------------
# Processing current number of iteration : 12
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.072934865951538
# ------------------------------------
# Processing current number of iteration : 13
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.7882790565490723
# ------------------------------------
# Processing current number of iteration : 14
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.945513963699341
# ------------------------------------
# Processing current number of iteration : 15
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 5.351885080337524
# ------------------------------------
# Processing current number of iteration : 16
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 4.2526750564575195
# ------------------------------------
# Processing current number of iteration : 17
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.6166841983795166
# ------------------------------------
# Processing current number of iteration : 18
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.7669179439544678
# ------------------------------------
# Processing current number of iteration : 19
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.6706008911132812
# ------------------------------------
# Processing current number of iteration : 20
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.712324857711792
# ------------------------------------
# Processing current number of iteration : 21
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.4271080493927
# ------------------------------------
# Processing current number of iteration : 22
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.8395979404449463
# ------------------------------------
# Processing current number of iteration : 23
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.3254168033599854
# ------------------------------------
# Processing current number of iteration : 24
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.1953940391540527
# ------------------------------------
# Processing current number of iteration : 25
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.1184656620025635
# ------------------------------------
# Processing current number of iteration : 26
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.7123777866363525
# ------------------------------------
# Processing current number of iteration : 27
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.6015641689300537
# ------------------------------------
# Processing current number of iteration : 28
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.8895223140716553
# ------------------------------------
# Processing current number of iteration : 29
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.4267289638519287
# ------------------------------------
# Processing current number of iteration : 30
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.9217681884765625
# ------------------------------------
# Processing current number of iteration : 31
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.98079514503479
# ------------------------------------
# Processing current number of iteration : 32
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.065081834793091
# ------------------------------------
# Processing current number of iteration : 33
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.776871919631958
# ------------------------------------
# Processing current number of iteration : 34
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.65745210647583
# ------------------------------------
# Processing current number of iteration : 35
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.5099570751190186
# ------------------------------------
# Processing current number of iteration : 36
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.1372690200805664
# ------------------------------------
# Processing current number of iteration : 37
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.7976751327514648
# ------------------------------------
# Processing current number of iteration : 38
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.315117835998535
# ------------------------------------
# Processing current number of iteration : 39
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.9262280464172363
# ------------------------------------
# Processing current number of iteration : 40
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.8311810493469238
# ------------------------------------
# Processing current number of iteration : 41
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.5895650386810303
# ------------------------------------
# Processing current number of iteration : 42
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.708517074584961
# ------------------------------------
# Processing current number of iteration : 43
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.8328452110290527
# ------------------------------------
# Processing current number of iteration : 44
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.6070783138275146
# ------------------------------------
# Processing current number of iteration : 45
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.5662338733673096
# ------------------------------------
# Processing current number of iteration : 46
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.6356680393218994
# ------------------------------------
# Processing current number of iteration : 47
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.8672170639038086
# ------------------------------------
# Processing current number of iteration : 48
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.6176340579986572
# ------------------------------------
# Processing current number of iteration : 49
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 5.537535905838013
# ------------------------------------
# Processing current number of iteration : 50
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.669261932373047
# Finished - 50 times.
# And the list of mean squared errors : [226.73242294814582, 142.7128420844282, 116.63822843325231, 94.31939453572083, 81.75799409022174, 74.60989302294234, 70.77565020196222, 68.2847076990703, 67.06586498431217, 66.42848694699131, 65.91152171776875, 66.04384117292096, 65.40320376674053, 63.55079861123915, 62.10829494309557, 59.599631906904676, 54.126930832795125, 52.91738105222965, 49.32149771504727, 47.30136398859753, 46.092415318271605, 45.65637011540312, 45.47428162487905, 45.43244480720977, 45.32664402309644, 45.25909289208505, 45.15575858877988, 45.13878528889847, 45.14636527551385, 45.156208690002494, 44.97215919588524, 44.923296092340976, 44.92162134864389, 44.8730089838839, 44.87444414142456, 44.89433127402044, 44.90319880073092, 44.885726414311, 44.829812782628736, 44.77679825066556, 44.81536515465128, 44.89767673375277, 44.88801791472847, 44.86757083676645, 44.93077668552134, 44.91768041797395, 44.861868492915626, 44.93338379503434, 44.89667400757303, 44.945426837065355]
# ------------------------------------------------------------------------
# The mean and the standard deviation of the mean squared errors are: 58.95 and 30.7, respectively

# %% [markdown]
# ## Report the mean and the standard deviation of the mean squared errors

# %%
name_of_experiment = "Normalized with one Hidden Layer and 50 epochs"

# Report the mean and the standard deviation of the mean squared errors
concrete_data_result_baseline = get_report(name_of_experiment, mean_mse, std_mse)
concrete_data_result_baseline
# Out:
#                                        Experiment  Mean MSE  Std Deviation MSE
# 0  Normalized with one Hidden Layer and 50 epochs     58.95               30.7

# %%
# Concat baseline dataframe into result
concrete_data_mse_and_rmse = pd.concat([concrete_data_mse_and_rmse, concrete_data_result_baseline], axis=0)

# Review the result dataframe
concrete_data_mse_and_rmse.reset_index(drop=True)
# Out:
#                                        Experiment  Mean MSE  Std Deviation MSE
# 0         Baseline of the Raw Data with 50 epochs     53.62              11.17
# 1  Normalized with one Hidden Layer and 50 epochs     58.95              30.70
# 2  Normalized with one Hidden Layer and 50 epochs     58.95              30.70

# %% [markdown]
# # C. Increate the number of epochs
#
# Repeat Part B but use 100 epochs this time for training.
#
# How does the mean of the mean squared errors compare to that from Step B?

# %% [markdown]
# ## Building and Training with the baseline model after normalizing the data with 100 epochs

# %%
# Evaluate the compiled model
model = build_model_with_one_hidden_layer(num_of_features=num_of_features)

mean_mse, std_mse = get_mean_and_std_of_mse(concrete_data_predictors_norm, 
                                            concrete_data_target, 
                                            model, 
                                            max_iteration=50, 
                                            epochs=100, verbose=0)
# Out:
# ------------------------------------
# Processing current number of iteration : 1
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.5591349601745605
# ------------------------------------
# Processing current number of iteration : 2
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.934518814086914
# ------------------------------------
# Processing current number of iteration : 3
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.8928751945495605
# ------------------------------------
# Processing current number of iteration : 4
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.9371676445007324
# ------------------------------------
# Processing current number of iteration : 5
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.978286027908325
# ------------------------------------
# Processing current number of iteration : 6
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.037116765975952
# ------------------------------------
# Processing current number of iteration : 7
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.984876871109009
# ------------------------------------
# Processing current number of iteration : 8
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.241029977798462
# ------------------------------------
# Processing current number of iteration : 9
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.308479070663452
# ------------------------------------
# Processing current number of iteration : 10
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.0839507579803467
# ------------------------------------
# Processing current number of iteration : 11
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.127454996109009
# ------------------------------------
# Processing current number of iteration : 12
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.967588186264038
# ------------------------------------
# Processing current number of iteration : 13
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.7532799243927
# ------------------------------------
# Processing current number of iteration : 14
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 4.130030870437622
# ------------------------------------
# Processing current number of iteration : 15
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.9171390533447266
# ------------------------------------
# Processing current number of iteration : 16
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.5936031341552734
# ------------------------------------
# Processing current number of iteration : 17
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.2390148639678955
# ------------------------------------
# Processing current number of iteration : 18
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 5.122589111328125
# ------------------------------------
# Processing current number of iteration : 19
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 5.328577041625977
# ------------------------------------
# Processing current number of iteration : 20
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.1843221187591553
# ------------------------------------
# Processing current number of iteration : 21
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.984151840209961
# ------------------------------------
# Processing current number of iteration : 22
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.6012721061706543
# ------------------------------------
# Processing current number of iteration : 23
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.5599160194396973
# ------------------------------------
# Processing current number of iteration : 24
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.052510976791382
# ------------------------------------
# Processing current number of iteration : 25
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.5050101280212402
# ------------------------------------
# Processing current number of iteration : 26
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.927337884902954
# ------------------------------------
# Processing current number of iteration : 27
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.965555191040039
# ------------------------------------
# Processing current number of iteration : 28
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 4.0151917934417725
# ------------------------------------
# Processing current number of iteration : 29
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 4.87654185295105
# ------------------------------------
# Processing current number of iteration : 30
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.0144190788269043
# ------------------------------------
# Processing current number of iteration : 31
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.3217248916625977
# ------------------------------------
# Processing current number of iteration : 32
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.4921038150787354
# ------------------------------------
# Processing current number of iteration : 33
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 4.074422121047974
# ------------------------------------
# Processing current number of iteration : 34
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 4.416399002075195
# ------------------------------------
# Processing current number of iteration : 35
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.97607684135437
# ------------------------------------
# Processing current number of iteration : 36
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.587003231048584
# ------------------------------------
# Processing current number of iteration : 37
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.497093915939331
# ------------------------------------
# Processing current number of iteration : 38
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.3258469104766846
# ------------------------------------
# Processing current number of iteration : 39
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.0025410652160645
# ------------------------------------
# Processing current number of iteration : 40
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.5723841190338135
# ------------------------------------
# Processing current number of iteration : 41
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.6988940238952637
# ------------------------------------
# Processing current number of iteration : 42
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 5.181425094604492
# ------------------------------------
# Processing current number of iteration : 43
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.6946098804473877
# ------------------------------------
# Processing current number of iteration : 44
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.420347213745117
# ------------------------------------
# Processing current number of iteration : 45
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 4.534631967544556
# ------------------------------------
# Processing current number of iteration : 46
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 4.020293712615967
# ------------------------------------
# Processing current number of iteration : 47
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.1876299381256104
# ------------------------------------
# Processing current number of iteration : 48
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.721435785293579
# ------------------------------------
# Processing current number of iteration : 49
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.7955708503723145
# ------------------------------------
# Processing current number of iteration : 50
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 4.0064377784729
# Finished - 50 times.
# And the list of mean squared errors : [137.7010524976072, 90.4356488363186, 70.35512214275793, 62.263449573281115, 57.2550173118829, 55.29711188074664, 54.37699311536383, 47.21209503288314, 45.18200969210158, 43.968250743513984, 42.96038222560669, 42.42181826734367, 41.928545759868726, 41.23136394394592, 40.8444709388292, 40.72824579546911, 40.317591815577494, 39.90971181872688, 39.56853046383708, 39.114516376911595, 38.988321712904934, 38.88302569284508, 38.81826524414492, 38.8765152399132, 38.878074840078504, 38.92193348656074, 38.8191855140765, 38.867433241178794, 38.997846064094944, 38.94707458053241, 38.70391183517936, 38.7589076381592, 38.674244518623304, 38.892763866967954, 38.76469791070721, 38.534253889494344, 38.52708659313599, 38.56202748998057, 38.307023272042315, 38.250331466461475, 37.72299525613979, 37.63272732998735, 37.452938863911136, 37.683197418179546, 37.63372454749531, 37.48537947323171, 37.52157273217439, 37.49854677247035, 37.49915426612162, 37.38436697481659]
# ------------------------------------------------------------------------
# The mean and the standard deviation of the mean squared errors are: 44.47 and 16.4, respectively

# %% [markdown]
# ## Report the mean and the standard deviation of the mean squared errors

# %%
name_of_experiment = "Normalized with one Hidden Layer and 100 epochs"

# Report the mean and the standard deviation of the mean squared errors
concrete_data_result_baseline = get_report(name_of_experiment, mean_mse, std_mse)
concrete_data_result_baseline
# Out:
#                                         Experiment  Mean MSE  \
# 0  Normalized with one Hidden Layer and 100 epochs     44.47
#
#    Std Deviation MSE
# 0               16.4

# %%
# Concat baseline dataframe into result
concrete_data_mse_and_rmse = pd.concat([concrete_data_mse_and_rmse, concrete_data_result_baseline], axis=0)

# Review the result dataframe
concrete_data_mse_and_rmse.reset_index(drop=True)
# Out:
#                                         Experiment  Mean MSE  \
# 0          Baseline of the Raw Data with 50 epochs     53.62
# 1   Normalized with one Hidden Layer and 50 epochs     58.95
# 2   Normalized with one Hidden Layer and 50 epochs     58.95
# 3  Normalized with one Hidden Layer and 100 epochs     44.47
#
#    Std Deviation MSE
# 0              11.17
# 1              30.70
# 2              30.70
# 3              16.40

# %% [markdown]
# # D. Increase the number of hidden layers
#
# Repeat part B but use a neural network with the following instead:
#
# - Three hidden layers, each of 10 nodes and ReLU activation function.
#
# How does the mean of the mean squared errors compare to that from Step B?

# %% [markdown]
# ## Building and Training with the model after normalizing the data with 50 epochs

# %%
# Evaluate the compiled model
model = build_model_with_three_hidden_layers(num_of_features=num_of_features)

mean_mse, std_mse = get_mean_and_std_of_mse(concrete_data_predictors_norm, 
                                            concrete_data_target, 
                                            model, 
                                            max_iteration=50, 
                                            epochs=50, 
                                            verbose=0)
# Out:
# ------------------------------------
# Processing current number of iteration : 1
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.5826680660247803
# ------------------------------------
# Processing current number of iteration : 2
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.0521719455718994
# ------------------------------------
# Processing current number of iteration : 3
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.036702871322632
# ------------------------------------
# Processing current number of iteration : 4
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.9125189781188965
# ------------------------------------
# Processing current number of iteration : 5
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.732224702835083
# ------------------------------------
# Processing current number of iteration : 6
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.6878490447998047
# ------------------------------------
# Processing current number of iteration : 7
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.108198881149292
# ------------------------------------
# Processing current number of iteration : 8
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.3272762298583984
# ------------------------------------
# Processing current number of iteration : 9
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.8364319801330566
# ------------------------------------
# Processing current number of iteration : 10
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.064258098602295
# ------------------------------------
# Processing current number of iteration : 11
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.3176040649414062
# ------------------------------------
# Processing current number of iteration : 12
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.9280610084533691
# ------------------------------------
# Processing current number of iteration : 13
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.8354909420013428
# ------------------------------------
# Processing current number of iteration : 14
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.8742363452911377
# ------------------------------------
# Processing current number of iteration : 15
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.1419191360473633
# ------------------------------------
# Processing current number of iteration : 16
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.447822093963623
# ------------------------------------
# Processing current number of iteration : 17
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.0643310546875
# ------------------------------------
# Processing current number of iteration : 18
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.3437490463256836
# ------------------------------------
# Processing current number of iteration : 19
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.9135067462921143
# ------------------------------------
# Processing current number of iteration : 20
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.8796627521514893
# ------------------------------------
# Processing current number of iteration : 21
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.184424877166748
# ------------------------------------
# Processing current number of iteration : 22
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.8803131580352783
# ------------------------------------
# Processing current number of iteration : 23
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.101533889770508
# ------------------------------------
# Processing current number of iteration : 24
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.9247870445251465
# ------------------------------------
# Processing current number of iteration : 25
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.9333209991455078
# ------------------------------------
# Processing current number of iteration : 26
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.1063740253448486
# ------------------------------------
# Processing current number of iteration : 27
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.3817429542541504
# ------------------------------------
# Processing current number of iteration : 28
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.0529820919036865
# ------------------------------------
# Processing current number of iteration : 29
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.967756986618042
# ------------------------------------
# Processing current number of iteration : 30
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.936530113220215
# ------------------------------------
# Processing current number of iteration : 31
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.4106650352478027
# ------------------------------------
# Processing current number of iteration : 32
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 4.1961071491241455
# ------------------------------------
# Processing current number of iteration : 33
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.711771249771118
# ------------------------------------
# Processing current number of iteration : 34
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.2101781368255615
# ------------------------------------
# Processing current number of iteration : 35
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.2156240940093994
# ------------------------------------
# Processing current number of iteration : 36
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.8859148025512695
# ------------------------------------
# Processing current number of iteration : 37
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 3.0422418117523193
# ------------------------------------
# Processing current number of iteration : 38
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.983422040939331
# ------------------------------------
# Processing current number of iteration : 39
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.9247469902038574
# ------------------------------------
# Processing current number of iteration : 40
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.476365804672241
# ------------------------------------
# Processing current number of iteration : 41
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.8585584163665771
# ------------------------------------
# Processing current number of iteration : 42
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.881782054901123
# ------------------------------------
# Processing current number of iteration : 43
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.173064947128296
# ------------------------------------
# Processing current number of iteration : 44
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.74377703666687
# ------------------------------------
# Processing current number of iteration : 45
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.8609862327575684
# ------------------------------------
# Processing current number of iteration : 46
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.890643835067749
# ------------------------------------
# Processing current number of iteration : 47
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.012349843978882
# ------------------------------------
# Processing current number of iteration : 48
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.011723041534424
# ------------------------------------
# Processing current number of iteration : 49
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 1.9642550945281982
# ------------------------------------
# Processing current number of iteration : 50
# Training set:  (721, 8) (721, 1)
# Testing set:  (309, 8) (309, 1)
# Duration (seconds): 2.089717149734497
# Finished - 50 times.
# And the list of mean squared errors : [91.13738169066542, 49.88947534831803, 43.23142267561821, 39.60249924777901, 37.79947582473276, 36.5102353839625, 35.593688682793015, 34.00928291791167, 33.37182996342897, 33.00751435957642, 33.20275911471875, 33.18606776225179, 33.4549915489424, 32.844931221084316, 32.08838678691854, 31.89655282305139, 31.450497268919072, 31.14865251814869, 30.94374139116586, 30.841734645776434, 31.804258845273438, 30.686681280196836, 30.77782028306185, 30.62646495347456, 30.558146314292333, 31.718573047518024, 30.12413991045389, 29.96636444575527, 30.261513810072323, 30.553038394403664, 29.934882223981386, 30.07418823444099, 30.707029104688996, 30.60373353391397, 29.88651935119419, 29.976701422355717, 30.40584954017357, 30.16903723571832, 30.07107938769155, 30.358895807160252, 30.021164829262307, 29.763308031460916, 30.08591022652162, 30.022111394925457, 31.2669157580392, 30.28104212878633, 30.33196652846373, 30.64541010484461, 29.764797188438443, 30.007881855891362]
# ------------------------------------------------------------------------
# The mean and the standard deviation of the mean squared errors are: 33.33 and 9.03, respectively

# %% [markdown]
# ## Report the mean and the standard deviation of the mean squared errors

# %%
name_of_experiment = "Normalized with 3 Hidden Layers and 50 epochs"

# Report the mean and the standard deviation of the mean squared errors
concrete_data_result_baseline = get_report(name_of_experiment, mean_mse, std_mse)
concrete_data_result_baseline
# Out:
#                                       Experiment  Mean MSE  Std Deviation MSE
# 0  Normalized with 3 Hidden Layers and 50 epochs     33.33               9.03

# %%
# Concat baseline dataframe into result
concrete_data_mse_and_rmse = pd.concat([concrete_data_mse_and_rmse, concrete_data_result_baseline], axis=0)

# Review the result dataframe
concrete_data_mse_and_rmse.reset_index(drop=True)
# Out:
#                                         Experiment  Mean MSE  \
# 0          Baseline of the Raw Data with 50 epochs     53.62
# 1   Normalized with one Hidden Layer and 50 epochs     58.95
# 2   Normalized with one Hidden Layer and 50 epochs     58.95
# 3  Normalized with one Hidden Layer and 100 epochs     44.47
# 4    Normalized with 3 Hidden Layers and 50 epochs     33.33
#
#    Std Deviation MSE
# 0              11.17
# 1              30.70
# 2              30.70
# 3              16.40
# 4               9.03

# %% [markdown]
# # Discussion

# %% [markdown]
# The mean squared error (MSE) indicates that close a regression model is the testing set. And the standard deviation of the residuals estimate the differences between the data set and thelinear regression model.
#
# The the modelin D-Normalized-3 Hidden Layers(50 epochs), which is trained with three hidden layers, each of 10 nodes and ReLU activation function, is the best one. Since mean of the MSE is **34.17**. Moreover, its error is lower than about *16* and **17** as compared with the trained model applying one hidden layer with *50* epochs and **100** epochs.
#
# Besides, when comparing to mean of the MSEs of baseline model, the MSE of **model (D)** is lower, about **35**.
#
# It interesting to note that the mean of the MSEs of baseline model **(B-Normalized-1 Hidden Layers(50 epochs))** is lower about **1** than the mean the MSEs of **model (C-Normalized-1 Hidden Layers(100 epochs))** which is trained by the normalized data and the same configuration of model, but model (C) did 100 epochs.
#
# In conclusion, several techniques can be applied to fine-tune the model such as normalizing the input data, thus improving the number of epochs or the number of hidden layers.
